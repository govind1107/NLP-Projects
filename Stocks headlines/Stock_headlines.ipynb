# %%
# Importing essential libraries
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Stock Headlines.csv',encoding = 'ISO-8859-1')

# %%
df.head()
# Out:
#          Date  Label                                               Top1  \
# 0  2000-01-03      0  A 'hindrance to operations': extracts from the...
# 1  2000-01-04      0                                          Scorecard
# 2  2000-01-05      0                  Coventry caught on counter by Flo
# 3  2000-01-06      1                      Pilgrim knows how to progress
# 4  2000-01-07      1                               Hitches and Horlocks
#
#                                  Top2  \
# 0                           Scorecard
# 1                 The best lake scene
# 2  United's rivals on the road to Rio
# 3                 Thatcher facing ban
# 4      Beckham off but United survive
#
#                                             Top3  \
# 0                Hughes' instant hit buoys Blues
# 1                  Leader: German sleaze inquiry
# 2  Thatcher issues defence before trial by video
# 3        McIlroy calls for Irish fighting spirit
# 4                        Breast cancer screening
#
#                                             Top4  \
# 0       Jack gets his skates on at ice-cold Alex
# 1                                  Cheerio, boyo
# 2  Police help Smith lay down the law at Everton
# 3                Leicester bin stadium blueprint
# 4                                    Alan Parker
#
#                                           Top5  \
# 0       Chaos as Maracana builds up for United
# 1                     The main recommendations
# 2  Tale of Trautmann bears two more retellings
# 3               United braced for Mexican wave
# 4      Guardian readers: are you all whingers?
#
#                                                 Top6  \
# 0  Depleted Leicester prevail as Elliott spoils E...
# 1                             Has Cubie killed fees?
# 2                                England on the rack
# 3  Auntie back in fashion, even if the dress look...
# 4                                   Hollywood Beyond
#
#                                               Top7  \
# 0                 Hungry Spurs sense rich pickings
# 1                           Has Cubie killed fees?
# 2  Pakistan retaliate with call for video of Walsh
# 3                    Shoaib appeal goes to the top
# 4                               Ashes and diamonds
#
#                                                 Top8  ...  \
# 0                  Gunners so wide of an easy target  ...
# 1                             Has Cubie killed fees?  ...
# 2               Cullinan continues his Cape monopoly  ...
# 3  Hussain hurt by 'shambles' but lays blame on e...  ...
# 4                   Whingers - a formidable minority  ...
#
#                                                Top16  \
# 0           Flintoff injury piles on woe for England
# 1                               On the critical list
# 2                        South Melbourne (Australia)
# 3  Putin admits Yeltsin quit to give him a head s...
# 4                             Most everywhere:  UDIs
#
#                                                Top17  \
# 0  Hunters threaten Jospin with new battle of the...
# 1                          The timing of their lives
# 2                                    Necaxa (Mexico)
# 3         BBC worst hit as digital TV begins to bite
# 4                       Most wanted:  Chloe lunettes
#
#                                             Top18  \
# 0             Kohl's successor drawn into scandal
# 1                                     Dear doctor
# 2                             Real Madrid (Spain)
# 3                     How much can you pay for...
# 4  Return of the cane 'completely off the agenda'
#
#                                                Top19  \
# 0               The difference between men and women
# 1  Irish court halts IRA man's extradition to Nor...
# 2                          Raja Casablanca (Morocco)
# 3                                 Christmas glitches
# 4                   From Sleepy Hollow to Greeneland
#
#                                                Top20  \
# 0                Sara Denver, nurse turned solicitor
# 1  Burundi peace initiative fades after rebels re...
# 2                               Corinthians (Brazil)
# 3  Upending a table, Chopping a line and Scoring ...
# 4              Blunkett outlines vision for over 11s
#
#                                                Top21  \
# 0     Diana's landmine crusade put Tories in a panic
# 1               PE points the way forward to the ECB
# 2                                 Tony's pet project
# 3   Scientific evidence 'unreliable', defence claims
# 4  Embattled Dobson attacks 'play now, pay later'...
#
#                                                Top22  \
# 0  Yeltsin's resignation caught opposition flat-f...
# 1  Campaigners keep up pressure on Nazi war crime...
# 2                            Al Nassr (Saudi Arabia)
# 3     Fusco wins judicial review in extradition case
# 4                                  Doom and the Dome
#
#                              Top23  \
# 0                 Russian roulette
# 1                   Jane Ratcliffe
# 2                Ideal Holmes show
# 3    Rebels thwart Russian advance
# 4  What is the north-south divide?
#
#                                                Top24  \
# 0                                           Sold out
# 1  Yet more things you wouldn't know without the ...
# 2               Pinochet leaves hospital after tests
# 3               Blair orders shake-up of failing NHS
# 4                          Aitken released from jail
#
#                           Top25
# 0            Recovering a title
# 1  Millennium bug fails to bite
# 2                  Useful links
# 3   Lessons of law's hard heart
# 4                    Gone aloft
#
# [5 rows x 27 columns]

# %%
df.isnull().sum()
# Out:
# Date     0
# Label    0
# Top1     0
# Top2     0
# Top3     0
# Top4     0
# Top5     0
# Top6     0
# Top7     0
# Top8     0
# Top9     0
# Top10    0
# Top11    0
# Top12    0
# Top13    0
# Top14    0
# Top15    0
# Top16    0
# Top17    0
# Top18    0
# Top19    0
# Top20    0
# Top21    0
# Top22    0
# Top23    1
# Top24    3
# Top25    3
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Label', 'Top1', 'Top2', 'Top3', 'Top4', 'Top5', 'Top6', 'Top7',
#        'Top8', 'Top9', 'Top10', 'Top11', 'Top12', 'Top13', 'Top14', 'Top15',
#        'Top16', 'Top17', 'Top18', 'Top19', 'Top20', 'Top21', 'Top22', 'Top23',
#        'Top24', 'Top25'],
#       dtype='object')

# %%
df_new = df.iloc[:,2:].astype(str)

# %%
df['review'] = df_new.agg(''.join,axis=1)

# %%
df.head()
# Out:
#          Date  Label                                               Top1  \
# 0  2000-01-03      0  A 'hindrance to operations': extracts from the...
# 1  2000-01-04      0                                          Scorecard
# 2  2000-01-05      0                  Coventry caught on counter by Flo
# 3  2000-01-06      1                      Pilgrim knows how to progress
# 4  2000-01-07      1                               Hitches and Horlocks
#
#                                  Top2  \
# 0                           Scorecard
# 1                 The best lake scene
# 2  United's rivals on the road to Rio
# 3                 Thatcher facing ban
# 4      Beckham off but United survive
#
#                                             Top3  \
# 0                Hughes' instant hit buoys Blues
# 1                  Leader: German sleaze inquiry
# 2  Thatcher issues defence before trial by video
# 3        McIlroy calls for Irish fighting spirit
# 4                        Breast cancer screening
#
#                                             Top4  \
# 0       Jack gets his skates on at ice-cold Alex
# 1                                  Cheerio, boyo
# 2  Police help Smith lay down the law at Everton
# 3                Leicester bin stadium blueprint
# 4                                    Alan Parker
#
#                                           Top5  \
# 0       Chaos as Maracana builds up for United
# 1                     The main recommendations
# 2  Tale of Trautmann bears two more retellings
# 3               United braced for Mexican wave
# 4      Guardian readers: are you all whingers?
#
#                                                 Top6  \
# 0  Depleted Leicester prevail as Elliott spoils E...
# 1                             Has Cubie killed fees?
# 2                                England on the rack
# 3  Auntie back in fashion, even if the dress look...
# 4                                   Hollywood Beyond
#
#                                               Top7  \
# 0                 Hungry Spurs sense rich pickings
# 1                           Has Cubie killed fees?
# 2  Pakistan retaliate with call for video of Walsh
# 3                    Shoaib appeal goes to the top
# 4                               Ashes and diamonds
#
#                                                 Top8  ...  \
# 0                  Gunners so wide of an easy target  ...
# 1                             Has Cubie killed fees?  ...
# 2               Cullinan continues his Cape monopoly  ...
# 3  Hussain hurt by 'shambles' but lays blame on e...  ...
# 4                   Whingers - a formidable minority  ...
#
#                                                Top17  \
# 0  Hunters threaten Jospin with new battle of the...
# 1                          The timing of their lives
# 2                                    Necaxa (Mexico)
# 3         BBC worst hit as digital TV begins to bite
# 4                       Most wanted:  Chloe lunettes
#
#                                             Top18  \
# 0             Kohl's successor drawn into scandal
# 1                                     Dear doctor
# 2                             Real Madrid (Spain)
# 3                     How much can you pay for...
# 4  Return of the cane 'completely off the agenda'
#
#                                                Top19  \
# 0               The difference between men and women
# 1  Irish court halts IRA man's extradition to Nor...
# 2                          Raja Casablanca (Morocco)
# 3                                 Christmas glitches
# 4                   From Sleepy Hollow to Greeneland
#
#                                                Top20  \
# 0                Sara Denver, nurse turned solicitor
# 1  Burundi peace initiative fades after rebels re...
# 2                               Corinthians (Brazil)
# 3  Upending a table, Chopping a line and Scoring ...
# 4              Blunkett outlines vision for over 11s
#
#                                                Top21  \
# 0     Diana's landmine crusade put Tories in a panic
# 1               PE points the way forward to the ECB
# 2                                 Tony's pet project
# 3   Scientific evidence 'unreliable', defence claims
# 4  Embattled Dobson attacks 'play now, pay later'...
#
#                                                Top22  \
# 0  Yeltsin's resignation caught opposition flat-f...
# 1  Campaigners keep up pressure on Nazi war crime...
# 2                            Al Nassr (Saudi Arabia)
# 3     Fusco wins judicial review in extradition case
# 4                                  Doom and the Dome
#
#                              Top23  \
# 0                 Russian roulette
# 1                   Jane Ratcliffe
# 2                Ideal Holmes show
# 3    Rebels thwart Russian advance
# 4  What is the north-south divide?
#
#                                                Top24  \
# 0                                           Sold out
# 1  Yet more things you wouldn't know without the ...
# 2               Pinochet leaves hospital after tests
# 3               Blair orders shake-up of failing NHS
# 4                          Aitken released from jail
#
#                           Top25  \
# 0            Recovering a title
# 1  Millennium bug fails to bite
# 2                  Useful links
# 3   Lessons of law's hard heart
# 4                    Gone aloft
#
#                                               review
# 0  A 'hindrance to operations': extracts from the...
# 1  ScorecardThe best lake sceneLeader: German sle...
# 2  Coventry caught on counter by FloUnited's riva...
# 3  Pilgrim knows how to progressThatcher facing b...
# 4  Hitches and HorlocksBeckham off but United sur...
#
# [5 rows x 28 columns]

# %%
# Importing essential libraries for visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Visualizing the count of 'Label' column from the dataset
plt.figure(figsize=(8,8))
sns.countplot(x='Label', data=df)
plt.xlabel('Stock Sentiments (0-Down/Same, 1-Up)')
plt.ylabel('Count')
plt.show()

# %%
df = df[['Label','review']]

# %%
stopwords_set = set(stopwords.words('english'))
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def cleaning(text):
  text = re.sub(pattern='[^a-zA-Z]', repl=' ', string=text)
  text = text.lower()
  words = text.split()
  words = [lemmatizer.lemmatize(word) for word in words if not word in stopwords_set]
  text = ' '.join(words)
  return text

# %%
df['cleaned_text'] = df['review'].apply(lambda x : cleaning(x))

# %%
df.head()
# Out:
#    Label                                             review  \
# 0      0  A 'hindrance to operations': extracts from the...
# 1      0  ScorecardThe best lake sceneLeader: German sle...
# 2      0  Coventry caught on counter by FloUnited's riva...
# 3      1  Pilgrim knows how to progressThatcher facing b...
# 4      1  Hitches and HorlocksBeckham off but United sur...
#
#                                         cleaned_text
# 0  hindrance operation extract leaked reportsscor...
# 1  scorecardthe best lake sceneleader german slea...
# 2  coventry caught counter flounited rival road r...
# 3  pilgrim know progressthatcher facing banmcilro...
# 4  hitch horlocksbeckham united survivebreast can...

# %%
X = df['cleaned_text']
y = df['Label']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_df=0.5, max_features=5000)
X_train = tfidf.fit_transform(X_train)
X_test = tfidf.transform(X_test)

# %%
# Fitting Naive Bayes to the Training set
from sklearn.naive_bayes import MultinomialNB
nb_classifier = MultinomialNB()
nb_classifier.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
nb_y_pred = nb_classifier.predict(X_test)

# %%
# Accuracy, Precision and Recall
from sklearn.metrics import accuracy_score, precision_score, recall_score
score1 = accuracy_score(y_test, nb_y_pred)
score2 = precision_score(y_test, nb_y_pred)
score3 = recall_score(y_test, nb_y_pred)
print("---- Scores ----")
print("Accuracy score is: {}%".format(round(score1*100,2)))
print("Precision score is: {}".format(round(score2,2)))
print("Recall score is: {}".format(round(score3,2)))
# Out:
# ---- Scores ----
# Accuracy score is: 49.82%
# Precision score is: 0.52
# Recall score is: 0.74

# %%
# Hyperparameter tuning the Naive Bayes Classifier
best_accuracy = 0.0
alpha_val = 0.0
for i in np.arange(0.1,1.1,0.1):
  temp_classifier = MultinomialNB(alpha=i)
  temp_classifier.fit(X_train, y_train)
  temp_y_pred = temp_classifier.predict(X_test)
  score = accuracy_score(y_test, temp_y_pred)
  print("Accuracy score for alpha={} is: {}%".format(round(i,1), round(score*100,2)))
  if score>best_accuracy:
    best_accuracy = score
    alpha_val = i
print('--------------------------------------------')
print('The best accuracy is {}% with alpha value as {}'.format(round(best_accuracy*100, 2), round(alpha_val,1)))
# Out:
# Accuracy score for alpha=0.1 is: 49.45%
# Accuracy score for alpha=0.2 is: 49.57%
# Accuracy score for alpha=0.3 is: 50.18%
# Accuracy score for alpha=0.4 is: 50.79%
# Accuracy score for alpha=0.5 is: 50.79%
# Accuracy score for alpha=0.6 is: 51.04%
# Accuracy score for alpha=0.7 is: 50.43%
# Accuracy score for alpha=0.8 is: 50.18%
# Accuracy score for alpha=0.9 is: 50.18%
# Accuracy score for alpha=1.0 is: 49.82%
# --------------------------------------------
# The best accuracy is 51.04% with alpha value as 0.6

# %%
from sklearn.linear_model import LogisticRegression
lr_classifier = LogisticRegression(random_state=0)
lr_classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
lr_y_pred = lr_classifier.predict(X_test)

# %%
# Accuracy, Precision and Recall
from sklearn.metrics import accuracy_score, precision_score, recall_score
score1 = accuracy_score(y_test, lr_y_pred)
score2 = precision_score(y_test, lr_y_pred)
score3 = recall_score(y_test, lr_y_pred)
print("---- Scores ----")
print("Accuracy score is: {}%".format(round(score1*100,2)))
print("Precision score is: {}".format(round(score2,2)))
print("Recall score is: {}".format(round(score3,2)))
# Out:
# ---- Scores ----
# Accuracy score is: 47.75%
# Precision score is: 0.5
# Recall score is: 0.61

# %%
best_accuracy = 0.0
c_val = 0.0
for i in np.arange(0.1,1.1,0.1):
  temp_classifier = LogisticRegression(C=i, random_state=0)
  temp_classifier.fit(X_train, y_train)
  temp_y_pred = temp_classifier.predict(X_test)
  score = accuracy_score(y_test, temp_y_pred)
  print("Accuracy score for C={} is: {}%".format(round(i,1), round(score*100,2)))
  if score>best_accuracy:
    best_accuracy = score
    c_val = i
print('--------------------------------------------')
print('The best accuracy is {}% with C value as {}'.format(round(best_accuracy*100, 2), round(c_val,1)))
# Out:
# Accuracy score for C=0.1 is: 52.5%
# Accuracy score for C=0.2 is: 51.16%
# Accuracy score for C=0.3 is: 50.43%
# Accuracy score for C=0.4 is: 49.09%
# Accuracy score for C=0.5 is: 49.09%
# Accuracy score for C=0.6 is: 48.72%
# Accuracy score for C=0.7 is: 48.84%
# Accuracy score for C=0.8 is: 49.09%
# Accuracy score for C=0.9 is: 47.62%
# Accuracy score for C=1.0 is: 47.75%
# --------------------------------------------
# The best accuracy is 52.5% with C value as 0.1

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=250,random_state=45).fit(X_train, y_train)

# %%
rf_y_pred = rf_model.predict(X_test)

# %%
# Accuracy, Precision and Recall
from sklearn.metrics import accuracy_score, precision_score, recall_score
score1 = accuracy_score(y_test, rf_y_pred)
score2 = precision_score(y_test, rf_y_pred)
score3 = recall_score(y_test, rf_y_pred)
print("---- Scores ----")
print("Accuracy score is: {}%".format(round(score1*100,2)))
print("Precision score is: {}".format(round(score2,2)))
print("Recall score is: {}".format(round(score3,2)))
# Out:
# ---- Scores ----
# Accuracy score is: 47.87%
# Precision score is: 0.5
# Recall score is: 0.61

# %%
# Hyperparameter tuning the Logistic Regression Classifier
best_accuracy = 0.0
c_val = 0.0
for i in [100,125,150,175,200,225,250,275,300]:
  temp_classifier = RandomForestClassifier(n_estimators=i,random_state=45).fit(X_train, y_train)
  temp_classifier.fit(X_train, y_train)
  temp_y_pred = temp_classifier.predict(X_test)
  score = accuracy_score(y_test, temp_y_pred)
  print("Accuracy score for C={} is: {}%".format(round(i,1), round(score*100,2)))
  if score>best_accuracy:
    best_accuracy = score
    c_val = i
print('--------------------------------------------')
print('The best accuracy is {}% with C value as {}'.format(round(best_accuracy*100, 2), round(c_val,1)))
# Out:
# Accuracy score for C=100 is: 47.02%
# Accuracy score for C=125 is: 48.23%
# Accuracy score for C=150 is: 48.11%
# Accuracy score for C=175 is: 48.96%
# Accuracy score for C=200 is: 49.33%
# Accuracy score for C=225 is: 48.96%
# Accuracy score for C=250 is: 47.87%
# Accuracy score for C=275 is: 48.96%
# Accuracy score for C=300 is: 50.43%
# --------------------------------------------
# The best accuracy is 50.43% with C value as 300

# %%
# Out:
# <3280x10000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 450345 stored elements in Compressed Sparse Row format>

# %%
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000, ngram_range=(1,3))
X = cv.fit_transform(df['cleaned_text']).toarray()

# %%
y = df['Label']

# %%
X
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
lr_classifier = LogisticRegression()
lr_classifier.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr_y_pred = lr_classifier.predict(X_test)

# %%
# Accuracy, Precision and Recall
from sklearn.metrics import accuracy_score, precision_score, recall_score
score1 = accuracy_score(y_test, lr_y_pred)
score2 = precision_score(y_test, lr_y_pred)
score3 = recall_score(y_test, lr_y_pred)
print("---- Scores ----")
print("Accuracy score is: {}%".format(round(score1*100,2)))
print("Precision score is: {}".format(round(score2,2)))
print("Recall score is: {}".format(round(score3,2)))
# Out:
# ---- Scores ----
# Accuracy score is: 50.18%
# Precision score is: 0.53
# Recall score is: 0.5

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense

# %%
### Vocabulary size
voc_size=10000

# %%
df.head()
# Out:
#    Label                                             review  \
# 0      0  A 'hindrance to operations': extracts from the...
# 1      0  ScorecardThe best lake sceneLeader: German sle...
# 2      0  Coventry caught on counter by FloUnited's riva...
# 3      1  Pilgrim knows how to progressThatcher facing b...
# 4      1  Hitches and HorlocksBeckham off but United sur...
#
#                                         cleaned_text
# 0  hindrance operation extract leaked reportsscor...
# 1  scorecardthe best lake sceneleader german slea...
# 2  coventry caught counter flounited rival road r...
# 3  pilgrim know progressthatcher facing banmcilro...
# 4  hitch horlocksbeckham united survivebreast can...

# %%
df.head()
# Out:
#    Label                                             review  \
# 0      0  A 'hindrance to operations': extracts from the...
# 1      0  ScorecardThe best lake sceneLeader: German sle...
# 2      0  Coventry caught on counter by FloUnited's riva...
# 3      1  Pilgrim knows how to progressThatcher facing b...
# 4      1  Hitches and HorlocksBeckham off but United sur...
#
#                                         cleaned_text
# 0  hindrance operation extract leaked reportsscor...
# 1  scorecardthe best lake sceneleader german slea...
# 2  coventry caught counter flounited rival road r...
# 3  pilgrim know progressthatcher facing banmcilro...
# 4  hitch horlocksbeckham united survivebreast can...

# %%
# Necessary libraries
from sklearn.model_selection import train_test_split
from sklearn import metrics

import re
import string

from tensorflow import keras
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding
from tensorflow.keras.layers import SimpleRNN, LSTM
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dropout

# %%
# Split target & features
X = df.drop(columns = ['Label','review'])
y = df['Label']

# Spliting train & test
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    stratify=y,
                                                    test_size=0.2,
                                                    random_state=42,
                                                    shuffle=True)

# %%
X['cleaned_text']
# Out:
# 0       hindrance operation extract leaked reportsscor...
# 1       scorecardthe best lake sceneleader german slea...
# 2       coventry caught counter flounited rival road r...
# 3       pilgrim know progressthatcher facing banmcilro...
# 4       hitch horlocksbeckham united survivebreast can...
#                               ...
# 4096    barclays rb share suspended trading tanking po...
# 4097    scientist australia want save great barrier re...
# 4098    explosion airport istanbulyemeni former presid...
# 4099    jamaica proposes marijuana dispenser tourist a...
# 4100    year old woman mexico city finally received bi...
# Name: cleaned_text, Length: 4101, dtype: object

# %%
# Keras takenization text data prep

num_words = None   # the most X frequent words is returned

# Tokenize data
tokenizer = Tokenizer(num_words=num_words)
tokenizer.fit_on_texts(X_train['cleaned_text'].tolist() + X_test['cleaned_text'].tolist())   # introduce text in list

# Get data word index
word_index = tokenizer.word_index

# Encode training/test data sentences into sequences
X_train_seq = tokenizer.texts_to_sequences(X_train['cleaned_text'].tolist())
X_test_seq = tokenizer.texts_to_sequences(X_test['cleaned_text'].tolist())

# Get max training sequence length
max_len = max([len(x) for x in X_train_seq])

# Pad the training/test sequences
X_train_pad = pad_sequences(X_train_seq, maxlen=max_len)
X_test_pad = pad_sequences(X_test_seq, maxlen=max_len)

# Output some results
print("\nPadded training shape:", X_train_pad.shape)
print("\nPadded test shape:", X_test_pad.shape)
# Out:
# Padded training shape: (3280, 480)
#
# Padded test shape: (821, 480)

# %%
# Basic RNN
model = Sequential()
model.add(Embedding(len(word_index) + 1,
                    50,     # embeds it in a 50-dimensional vector
                    input_length=max_len))
model.add(SimpleRNN(100))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 480, 50)           4984500
#
#  simple_rnn_2 (SimpleRNN)    (None, 100)               15100
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 4999701 (19.07 MB)
# Trainable params: 4999701 (19.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
batch_size = 512

model.fit(X_train_pad, y_train, epochs=5, batch_size=batch_size)
# Out:
# Epoch 1/5
# 7/7 [==============================] - 9s 1s/step - loss: 0.7014 - accuracy: 0.5027
# Epoch 2/5
# 7/7 [==============================] - 7s 954ms/step - loss: 0.6280 - accuracy: 0.6912
# Epoch 3/5
# 7/7 [==============================] - 7s 963ms/step - loss: 0.5063 - accuracy: 0.8762
# Epoch 4/5
# 7/7 [==============================] - 8s 1s/step - loss: 0.4544 - accuracy: 0.8976
# Epoch 5/5
# 7/7 [==============================] - 7s 1s/step - loss: 0.3149 - accuracy: 0.9619

# %%
# Setting up the evaluation metrics
def roc_auc(predictions,target):

    fpr, tpr, thresholds = metrics.roc_curve(target, predictions)
    roc_auc = metrics.auc(fpr, tpr)
    return roc_auc

# %%
scores = model.predict(X_test_pad)
print("AUC: %.2f%%" % (roc_auc(scores,y_test)))
# Out:
# 26/26 [==============================] - 2s 89ms/step
# AUC: 0.53%

# %%
#LSTM

# %%
model = Sequential()
model.add(Embedding(len(word_index) + 1,
                    50,     # embeds it in a 50-dimensional vector
                    input_length=max_len))

model.add(LSTM(100, dropout=0.3, recurrent_dropout=0.3))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 480, 50)           4984500
#
#  lstm (LSTM)                 (None, 100)               60400
#
#  dense_2 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 5045001 (19.25 MB)
# Trainable params: 5045001 (19.25 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
batch_size = 256

model.fit(X_train_pad, y_train, epochs=5, batch_size=batch_size)
# Out:
# Epoch 1/5
# 13/13 [==============================] - 57s 4s/step - loss: 0.6922 - accuracy: 0.5293
# Epoch 2/5
# 13/13 [==============================] - 53s 4s/step - loss: 0.6861 - accuracy: 0.5280
# Epoch 3/5
# 13/13 [==============================] - 44s 3s/step - loss: 0.7899 - accuracy: 0.6777
# Epoch 4/5
# 13/13 [==============================] - 46s 4s/step - loss: 0.5814 - accuracy: 0.9168
# Epoch 5/5
# 13/13 [==============================] - 44s 3s/step - loss: 0.3773 - accuracy: 0.9143

# %%
scores = model.predict(X_test_pad)
print("AUC: %.2f%%" % (roc_auc(scores,y_test)))
# Out:
# 26/26 [==============================] - 5s 173ms/step
# AUC: 0.49%
